# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import sys
import json
from dotenv import load_dotenv
import pandas as pd
import datetime
import pytz
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # Connecting to Spotify API

# %%
load_dotenv()
if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("usage: python3 file.py [username]")
    sys.exit()

# %%
scope = "user-library-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

# %%
playlists_res = sp.current_user_playlists()['items']
playlists = {}

for item in playlists_res:
  playlists[item['name']] = item['id']

playlists
# Out:
# {'sum': '6URjLae4AnvscdYVVB9Tqq',
#  'rihanna': '76QhOFRR5kyyrbupyT9R9I',
#  'RO tation': '6eQTWnnnbFDm3QRy7lgSsr',
#  'dj': '7BKQPJIKcp9mKV24LyLq61',
#  'chill': '1XPdaFPovJmoL9OzDAYJ5Z',
#  'old': '3Ehc9YycykfZ6ZvZ6GlIt2'}

# %% [markdown]
# # Constructing Input Data From Playlist

# %%
id = playlists['RO tation'] # This is what the input to the model will be, playlist ID
def tracks_from_playlist(id):
    """
    Given a playlist id, returns a pandas dataframe consisting of key elements of each song
    """
    playlist = sp.playlist(id)
    tracks = []
    for item in playlist['tracks']['items']:
        if item['track']['id'] is not None:
            track = item['track']
            track_id = track['id']
            artist_ids = [artist['id'] for artist in track['artists']] if len(track['artists']) > 0 else None
            artist_names = [artist['name'] for artist in track['artists']] if len(track['artists']) > 0 else None
            track_info = {
                'track_name': track['name'],
                'track_id': track_id,
                'artists': artist_names,
                'artist_ids': artist_ids,
                'album_name': track['album']['name'],
                'duration_ms': track['duration_ms'],
                'explicit': track['explicit'],
                'popularity': track['popularity'],
                'date_added': item['added_at']
            }
            tracks.append(track_info)

    tracks_df = pd.DataFrame(tracks)
    tracks_df['date_added'] = pd.to_datetime(tracks_df['date_added'], utc=True)
    now = datetime.datetime.now(pytz.utc)
    tracks_df['months_since_added'] = tracks_df['date_added'].apply(lambda x: relativedelta(now, x).months)
    tracks_df = tracks_df.drop(['date_added'], axis=1)

    return tracks_df

# rotation_df = tracks_from_playlist(id)
# rotation_df

# %%
def extract_tracks_features(ids):
  """
  Given a list of track ids, returns a pandas dataframe of key audio features of each track
  """
  audio_features_list = []
  for track_id in ids:
    if track_id is not None:
      audio_features = sp.audio_features(track_id)[0]
      audio_features_list.append(audio_features)

  # convert list of dictionaries to Pandas DataFrame
  audio_features_df = pd.DataFrame.from_records(audio_features_list, columns=audio_features_list[0].keys())

  # add track ID column to DataFrame
  audio_features_df['track_id'] = ids

  # re-order columns to put track_id first
  cols = audio_features_df.columns.tolist()
  cols = cols[-1:] + cols[:-1]
  audio_features_df = audio_features_df[cols]
  audio_features_df = audio_features_df.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'track_id'], axis=1)
  return audio_features_df

# tracks_df = extract_tracks_features(tracks_from_playlist(id)['track_id'])
# tracks_df

# %%
tracks_df1 = tracks_from_playlist(id)
tracks_df2 = extract_tracks_features(tracks_df1['track_id'])
playlist_df = pd.concat([tracks_df1,tracks_df2], axis=1)
playlist_df
# Out:
#                                            track_name                track_id
# 0                                       Favorite Song  1sFstGV1Z3Aw5TDFCiT7vK  \
# 1             No Problem (feat. Lil Wayne & 2 Chainz)  0v9Wz8o0BT8DU38R4ddjeH
# 2   All We Got (feat. Kanye West & Chicago Childre...  3ZLyt2ndLFBh148XRYjYYZ
# 3                                          Lord Knows  1QBwk6GTCxVdC2hoSw9tlM
# 4           Rock N Roll (feat. Kanye West & Kid Cudi)  1ZM8toCOlnfBKJdvR8GqUq
# ..                                                ...                     ...
# 94  The Good, The Bad, The Ugly (feat. Kanye West)...  52uU5uNt9lOstGCc6C7QEJ
# 95                                      Herside Story  564oa00vY05d1uYnTEAAmE
# 96                                 Surf (feat. Gunna)  6igOR5QCn09zAVF2ikZjsV
# 97                       Bad Bad Bad (feat. Lil Baby)  1GeNui6m825V8jP4uKiIaH
# 98                        Shoota (feat. Lil Uzi Vert)  2BJSMvOGABRxokHKB0OI8i
#
#                                               artists
# 0               [Chance the Rapper, Childish Gambino]  \
# 1            [Chance the Rapper, Lil Wayne, 2 Chainz]
# 2   [Chance the Rapper, Kanye West, Chicago Childr...
# 3                                  [Drake, Rick Ross]
# 4                     [Pusha T, Kanye West, Kid Cudi]
# ..                                                ...
# 94                          [Consequence, Kanye West]
# 95                            [GoldLink, Hare Squead]
# 96                                [Young Thug, Gunna]
# 97                             [Young Thug, Lil Baby]
# 98                      [Playboi Carti, Lil Uzi Vert]
#
#                                            artist_ids
# 0    [1anyVhU62p31KFi8MEzkbf, 73sIBHcqh3Z3NyqHKZ7FOL]  \
# 1   [1anyVhU62p31KFi8MEzkbf, 55Aa2cqylxrFIXC767Z86...
# 2   [1anyVhU62p31KFi8MEzkbf, 5K4W6rqBFWDnAN6FQUkS6...
# 3    [3TVXtAsR1Inumwj472S9r4, 1sBkRIssrMs1AbVkOJbc7a]
# 4   [0ONHkAv9pCAFxb0zJwDNTy, 5K4W6rqBFWDnAN6FQUkS6...
# ..                                                ...
# 94   [5KkgZ31b9eDwkvo9oMIrSm, 5K4W6rqBFWDnAN6FQUkS6x]
# 95   [5XenQ7XfcvQdfIbpLEFaKQ, 3OqgnoaUHWX4ih4oAL0zzQ]
# 96   [50co4Is1HCEo8bhOyUWKpn, 2hlmm7s2ICUX0LVIhVFlZQ]
# 97   [50co4Is1HCEo8bhOyUWKpn, 5f7VJjfbwm532GiveGC0ZK]
# 98   [699OTQXzgjhIYAHMy9RyPD, 4O15NlyKLIASxsJ0PrXPfz]
#
#                  album_name  duration_ms  explicit  popularity
# 0                  Acid Rap       185062      True          62  \
# 1             Coloring Book       304606      True          67
# 2             Coloring Book       203794     False          57
# 3        Take Care (Deluxe)       307640      True          64
# 4           It's Almost Dry       233922      True          59
# ..                      ...          ...       ...         ...
# 94  Don't Quit Your Day Job       251906      True          50
# 95             At What Cost       183760      True          61
# 96              So Much Fun       184093      True          55
# 97              So Much Fun       149040      True          68
# 98                  Die Lit       153800      True          78
#
#     months_since_added  danceability  ...  loudness  mode  speechiness
# 0                    3         0.725  ...    -9.030     1        0.377  \
# 1                    3         0.652  ...    -5.192     0        0.174
# 2                    3         0.531  ...    -8.615     0        0.462
# 3                    3         0.417  ...    -5.551     0        0.367
# 4                    3         0.687  ...    -4.573     1        0.191
# ..                 ...           ...  ...       ...   ...          ...
# 94                   0         0.473  ...    -3.372     0        0.444
# 95                   0         0.885  ...    -5.487     1        0.286
# 96                   0         0.930  ...    -8.053     1        0.250
# 97                   0         0.974  ...    -8.888     1        0.184
# 98                   0         0.673  ...    -8.433     0        0.196
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0         0.0321          0.000000    0.0504    0.811  155.918       185062  \
# 1         0.1560          0.000000    0.1230    0.788  135.018       304607
# 2         0.3080          0.000002    0.0835    0.398  131.921       203794
# 3         0.0786          0.000000    0.8340    0.303  167.579       307640
# 4         0.0526          0.000000    0.0718    0.359  156.141       233923
# ..           ...               ...       ...      ...      ...          ...
# 94        0.0271          0.000000    0.0784    0.721   94.571       251907
# 95        0.6560          0.000004    0.1050    0.754  148.034       183760
# 96        0.1010          0.000000    0.0992    0.596  140.987       184093
# 97        0.0976          0.000000    0.1510    0.892  111.959       149040
# 98        0.1880          0.000000    0.1220    0.470  153.075       153800
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 94               4
# 95               4
# 96               4
# 97               4
# 98               4
#
# [99 rows x 22 columns]

# %% [markdown]
# # Generate Recommendations
